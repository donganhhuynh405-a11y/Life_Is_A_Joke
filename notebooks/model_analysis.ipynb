# %% [markdown]
# # ML Model Analysis
#
# Notebook for analysing trained ML models: performance metrics, SHAP explanations, and regime detection.

# %%
import sys
sys.path.insert(0, '..')

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from src.ml_advanced.model_registry import ModelRegistry
from src.ml_advanced.explainability import SHAPExplainer, ModelExplainabilityReport
from src.ml_advanced.meta_learning import RegimeDetector

print('Imports OK')

# %% [markdown]
# ## 1. Load a Registered Model

# %%
registry = ModelRegistry(registry_root='../models/registry')
print('Registered models:', registry.list_models())

# %% [markdown]
# ## 2. SHAP Global Feature Importance

# %%
# Replace with your actual model and data
# explainer = SHAPExplainer(model=my_model)
# importance = explainer.global_importance(X_test)
# print(importance)
print('Configure model and X_test above.')

# %% [markdown]
# ## 3. Regime Detection

# %%
# detector = RegimeDetector(n_regimes=4)
# detector.fit(X_features)
# labels = detector.predict(X_features)
# print('Regime distribution:', np.bincount(labels))
print('Configure X_features above.')
