# %% [markdown]
# # Feature Exploration
#
# Notebook for exploring and visualising engineered features for the trading bot.

# %%
import sys
sys.path.insert(0, '..')

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from src.ml_advanced.feature_engineering import FeatureEngineer

print('Imports OK')

# %% [markdown]
# ## 1. Load OHLCV Data

# %%
# Replace with your data loader
# df = pd.read_csv('../data/BTCUSDT_1h.csv', parse_dates=['timestamp'], index_col='timestamp')
# print(df.shape)
print('Load your OHLCV data above.')

# %% [markdown]
# ## 2. Build Features

# %%
# engineer = FeatureEngineer()
# df_features = engineer.build_all_features(df)
# print(f'Features: {df_features.shape[1]} columns, {df_features.shape[0]} rows')
# df_features.tail()
print('Uncomment above after loading data.')

# %% [markdown]
# ## 3. Correlation Heatmap

# %%
# feature_cols = engineer.get_feature_columns(df_features)
# corr = df_features[feature_cols].corr()
# plt.figure(figsize=(14, 12))
# plt.title('Feature Correlation Matrix')
# plt.imshow(corr.values, cmap='RdBu_r', vmin=-1, vmax=1)
# plt.colorbar()
# plt.xticks(range(len(feature_cols)), feature_cols, rotation=90)
# plt.yticks(range(len(feature_cols)), feature_cols)
# plt.tight_layout()
# plt.show()
print('Uncomment above after building features.')

# %% [markdown]
# ## 4. Feature Distribution

# %%
# Select a few key features and plot their distributions
# key_features = ['log_return_1', 'rsi_14', 'MACD', 'BB_pct', 'atr_14']
# df_features[key_features].hist(bins=50, figsize=(16, 10))
# plt.tight_layout()
# plt.show()
print('Uncomment above after building features.')
